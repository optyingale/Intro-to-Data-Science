# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **sports or athletics** (see below) for the region of **Jakarta, Jakarta, Indonesia**, or **Indonesia** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Jakarta, Jakarta, Indonesia** to Ann Arbor, USA. In that case at least one source file must be about **Jakarta, Jakarta, Indonesia**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Jakarta, Jakarta, Indonesia** and **sports or athletics**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **sports or athletics**?  For this category we are interested in sporting events or athletics broadly, please feel free to creatively interpret the category when building your research question!
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %matplotlib notebook

sea_games = pd.read_csv('https://gist.githubusercontent.com/lenguyenthedat/001b1ab5f2d290cd8fdc/raw/2f56163a2a320cae82eabb75c0767033d4d8cdc2/SEA%2520Games%2520Results.csv')

Nation = ['Indonesia', 'Malaysia', 'Philippines', 'Singapore', 'Thailand','Vietnam']
sea_games = sea_games[sea_games.Nation.isin(Nation)]

#sea_games.fillna(value = 259)

col = ["Nation","Gold","Silver","Bronze"]
sea_games.set_value(227, "Bronze", 102)
sea_games = sea_games.astype({"Gold": "int","Silver": "int","Bronze": "int" })
sea_games = sea_games[col].sort_values("Nation", ascending = True).groupby("Nation")["Gold","Silver","Bronze"].sum()
sea_games["Score"] = sea_games["Gold"]*3 + sea_games["Silver"]*2 + sea_games["Bronze"]*1

sea_games = sea_games.reset_index()

# %%
Summer_Olympics_Medal_0 = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/2016_Summer_Olympics_medal_table.csv')
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0[Summer_Olympics_Medal_0.NOC.isin(Nation)]
Summer_Olympics_Medal_0["Year"] = "2016"

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/2012_Summer_Olympics_medal_table.csv')
temp["Year"] = "2012"
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.append(temp[temp.NOC.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/2008_Summer_Olympics_medal_table.csv')
temp["Year"] = "2008"
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.append(temp[temp.NOC.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/2004_Summer_Olympics_medal_table.csv')
temp["Year"] = "2004"
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.append(temp[temp.NOC.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/2000_Summer_Olympics_medal_table.csv')
temp["Year"] = "2000"
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.append(temp[temp.NOC.isin(Nation)])


temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1992_Summer_Olympics_medal_table.csv')
temp["Year"] = "1992"
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.append(temp[temp.NOC.isin(Nation)])

#======================================================================

Summer_Olympics_Medal_1 = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1996_Summer_Olympics_medal_table.csv')
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1[Summer_Olympics_Medal_1.Nation.isin(Nation)]
Summer_Olympics_Medal_1["Year"] = "1996"

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1988_Summer_Olympics_medal_table.csv')
temp["Year"] = "1988"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1984_Summer_Olympics_medal_table.csv')
temp["Year"] = "1984"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1980_Summer_Olympics_medal_table.csv')
temp["Year"] = "1980"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1976_Summer_Olympics_medal_table.csv')
temp["Year"] = "1976"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1972_Summer_Olympics_medal_table.csv')
temp["Year"] = "1972"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1968_Summer_Olympics_medal_table.csv')
temp["Year"] = "1968"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1964_Summer_Olympics_medal_table.csv')
temp["Year"] = "1964"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1960_Summer_Olympics_medal_table.csv')
temp["Year"] = "1960"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

temp = pd.read_csv('https://raw.githubusercontent.com/thoera/summer_olympics/master/data/1956_Summer_Olympics_medal_table.csv')
temp["Year"] = "1956"
Summer_Olympics_Medal_1 = Summer_Olympics_Medal_1.append(temp[temp.Nation.isin(Nation)])

Summer_Olympics_Medal_0.rename(columns={"NOC": "Nation"}).append(Summer_Olympics_Medal_1)

Summer_Olympics_Medal_0

col = ["NOC","Gold","Silver","Bronze"]
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.astype({"Gold": "int","Silver": "int","Bronze": "int" })
Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0[col].sort_values("NOC", ascending = True).groupby("NOC")["Gold","Silver","Bronze"].sum()
Summer_Olympics_Medal_0["Score"] = Summer_Olympics_Medal_0["Gold"]*3 + Summer_Olympics_Medal_0["Silver"]*2 + Summer_Olympics_Medal_0["Bronze"]*1

Summer_Olympics_Medal_0 = Summer_Olympics_Medal_0.reset_index()

#Summer_Olympics_Medal_0

# %%
x = np.arange(len(Nation))  # the label locations
width = 0.40  # the width of the bars

fig, ax = plt.subplots()

#p1 = ax.bar(range(sea_games.shape[0]), sea_games.Score)
#p2 = ax.bar(range(Summer_Olympics_Medal_0.shape[0])+2, Summer_Olympics_Medal_0.Score)

ax2 = ax.twinx()
ax.set_ylim(0,14000)
ax2.set_ylim(0,70)

rects1 = ax.bar((x - width/2)-0.02, sea_games.Score, width, label='Sea Games', color='g')
rects2 = ax2.bar((x + width/2)+0.02, Summer_Olympics_Medal_0.Score, width, label='Summer Olympics', color='b')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores\nGold=3, Silver=2, Bronze=1',fontsize=10)
ax.set_xlabel('Nation',fontsize=10)
ax.set_title('Summer Olympics and Sea Games Score comparison between (1956 to 2015)\nIndonesia, Malaysia, Philippines, Singapore, Thailand, and Vietnam',size=10)
ax.set_xticks(x)
ax.set_xticklabels(Nation)
ax.legend(loc=0)
ax2.legend(loc=2)
ax.axhline(y = sea_games.Score.mean(), linestyle="--", color = 'g', alpha = 0.3)
ax2.axhline(y = Summer_Olympics_Medal_0.Score.mean(), linestyle="--", color = 'b', alpha = 0.3)

def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{:,}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', size=8, color='g')
        ax2.annotate('{:,}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom', size=8, color='b')

autolabel(rects1)
autolabel(rects2)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
